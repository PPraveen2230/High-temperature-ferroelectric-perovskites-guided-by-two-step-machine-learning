# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# TESTING THE DATASET

# %% [markdown]
# <p style="
#     padding: 10px;
#     background-color: darkgreen;
#     margin: 0;
#     color: #ffffff;
#     font-family: 'Trebuchet';
#     font-size: 24px;
#     text-align: center;
#     border: 3px solid green;
#     border-radius: 10px 30px;
#     overflow: hidden;
#     font-weight: bold;
#     text-transform: uppercase;
# ">Table of Contents</p>

# %% [markdown]
# <div style="border: 3px solid #A084CA; background-color: green; padding: 10px;">
#   <ul>
#     <li>
#       <strong><a href="#1" style="color: #ffffff;">Step 1: Import Necessary Libraries</a></strong>
#     </li>
#     <li>
#       <strong><a href="#2" style="color: #ffffff;">Step 2: Load the Dataset</a></strong>
#     </li>
#     <li>
#       <strong><a href="#3" style="color: #ffffff;">Step 3: Basic Data Exploration</a></strong>
#     </li>
#     <li>
#       <strong><a href="#4" style="color: #ffffff;">Step 4: Data Visualization</a></strong>
#     </li>
#      <li>
#       <strong><a href="#5" style="color: #ffffff;">Step 5: Data Preprocessing</a></strong>
#     </li>
#     <li>
#       <strong><a href="#6" style="color: #ffffff;">Step 6: Model Building</a></strong>
#     </li>
#   </ul>
# </div>

# %% [markdown]
# <a id="1"></a>
# <p style="
#     padding: 10px;
#     background-color: darkgreen;
#     margin: 0;
#     color: #ffffff;
#     font-family: 'Trebuchet';
#     font-size: 24px;
#     text-align: center;
#     border: 3px solid green;
#     border-radius: 10px 30px;
#     overflow: hidden;
#     font-weight: bold;
#     text-transform: uppercase;
# "> Import Necessary Libraries</p>

# %%
#IMPORT THE LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import sys
if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %% [markdown]
# <a id="2"></a>
#
# <p style="
#     padding: 10px;
#     background-color: darkgreen;
#     margin: 0;
#     color: #ffffff;
#     font-family: 'Trebuchet';
#     font-size: 24px;
#     text-align: center;
#     border: 3px solid green;
#     border-radius: 10px 30px;
#     overflow: hidden;
#     font-weight: bold;
#     text-transform: uppercase;
# ">Load the Dataset</p>

# %%
# Load the dataset
df = pd.read_csv('classification_dataset.csv')

original_df = df.copy(deep=True)
display(df.head(10))
# Out:
#    Comoound  x(BiMe1Me2)O3 Me1 Me2 Me3  frac-Me1  frac-Me2  frac-Me3  \
# 0  Bi(GaSc)           0.45  Ga  Sc  Ti      0.25      0.75       0.0
# 1  Bi(GaSc)           0.40  Ga  Sc  Ti      0.25      0.75       0.0
# 2  Bi(GaSc)           0.38  Ga  Sc  Ti      0.25      0.75       0.0
# 3  Bi(GaSc)           0.36  Ga  Sc  Ti      0.25      0.75       0.0
# 4  Bi(GaSc)           0.30  Ga  Sc  Ti      0.25      0.75       0.0
# 5  Bi(GaSc)           0.20  Ga  Sc  Ti      0.25      0.75       0.0
# 6   Bi(MgW)           0.80  Mg   W  Ti      0.75      0.25       0.0
# 7   Bi(MgW)           0.70  Mg   W  Ti      0.75      0.25       0.0
# 8   Bi(MgW)           0.65  Mg   W  Ti      0.75      0.25       0.0
# 9   Bi(MgW)           0.60  Mg   W  Ti      0.75      0.25       0.0
#
#    PT-content  Tolerance_Factor  Valence_Electron_Number  \
# 0        0.55            0.9813                      8.0
# 1        0.60            0.9864                      8.0
# 2        0.62            0.9884                      8.0
# 3        0.64            0.9904                      8.0
# 4        0.70            0.9966                      8.0
# 5        0.80            1.0068                      8.0
# 6        0.20            0.9541                      8.0
# 7        0.30            0.9633                      8.0
# 8        0.35            0.9678                      8.0
# 9        0.40            0.9724                      8.0
#
#    Martynov_Batsanov_Electronegativity  Ideal_Bond_Length_Sum  \
# 0                               3.7395                 3.9208
# 1                               3.7440                 3.9215
# 2                               3.7458                 3.9218
# 3                               3.7476                 3.9221
# 4                               3.7530                 3.9229
# 5                               3.7620                 3.9243
# 6                               3.6120                 3.8606
# 7                               3.6330                 3.8689
# 8                               3.6435                 3.8731
# 9                               3.6540                 3.8772
#
#    Mendeleev_Number Formability
# 0          118.9375          No
# 1          119.5000          No
# 2          119.7250          No
# 3          119.9500          No
# 4          120.6250         Yes
# 5          121.7500         Yes
# 6          144.6000          No
# 7          142.0250          No
# 8          140.7375          No
# 9          139.4500          No

# %%
print('\n\033[1mInference:\033[0m The Dataset consists of {} features & {} materials.'.format(df.shape[1], df.shape[0]))
# Out:
# Inference: The Dataset consists of 15 features & 192 materials.

# %%
df['Formability'] = df['Formability'].map({'No': 0, 'Yes': 1})
df = df.rename(columns={'Comoound': 'Compound'})
# Display the first few rows of the DataFrame to verify the changes
df.head()
# Out:
#    Compound  x(BiMe1Me2)O3 Me1 Me2 Me3  frac-Me1  frac-Me2  frac-Me3  \
# 0  Bi(GaSc)           0.45  Ga  Sc  Ti      0.25      0.75       0.0
# 1  Bi(GaSc)           0.40  Ga  Sc  Ti      0.25      0.75       0.0
# 2  Bi(GaSc)           0.38  Ga  Sc  Ti      0.25      0.75       0.0
# 3  Bi(GaSc)           0.36  Ga  Sc  Ti      0.25      0.75       0.0
# 4  Bi(GaSc)           0.30  Ga  Sc  Ti      0.25      0.75       0.0
#
#    PT-content  Tolerance_Factor  Valence_Electron_Number  \
# 0        0.55            0.9813                      8.0
# 1        0.60            0.9864                      8.0
# 2        0.62            0.9884                      8.0
# 3        0.64            0.9904                      8.0
# 4        0.70            0.9966                      8.0
#
#    Martynov_Batsanov_Electronegativity  Ideal_Bond_Length_Sum  \
# 0                               3.7395                 3.9208
# 1                               3.7440                 3.9215
# 2                               3.7458                 3.9218
# 3                               3.7476                 3.9221
# 4                               3.7530                 3.9229
#
#    Mendeleev_Number  Formability
# 0          118.9375            0
# 1          119.5000            0
# 2          119.7250            0
# 3          119.9500            0
# 4          120.6250            1

# %% [markdown]
# <a id="3"></a>
#
# <p style="
#     padding: 10px;
#     background-color: darkgreen;
#     margin: 0;
#     color: #ffffff;
#     font-family: 'Trebuchet';
#     font-size: 24px;
#     text-align: center;
#     border: 3px solid green;
#     border-radius: 10px 30px;
#     overflow: hidden;
#     font-weight: bold;
#     text-transform: uppercase;
# ">Basic Data Exploration</p>

# %%
# LISTING OUT THE COLUMNS
df.columns
# Out:
# Index(['Compound', 'x(BiMe1Me2)O3', 'Me1', 'Me2', 'Me3', 'frac-Me1',
#        'frac-Me2', 'frac-Me3', 'PT-content', 'Tolerance_Factor',
#        'Valence_Electron_Number', 'Martynov_Batsanov_Electronegativity',
#        'Ideal_Bond_Length_Sum', 'Mendeleev_Number', 'Formability'],
#       dtype='object')

# %%
# Get data types of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Compound                             192 non-null    object
#  1   x(BiMe1Me2)O3                        192 non-null    float64
#  2   Me1                                  192 non-null    object
#  3   Me2                                  192 non-null    object
#  4   Me3                                  192 non-null    object
#  5   frac-Me1                             192 non-null    float64
#  6   frac-Me2                             192 non-null    float64
#  7   frac-Me3                             192 non-null    float64
#  8   PT-content                           192 non-null    float64
#  9   Tolerance_Factor                     192 non-null    float64
#  10  Valence_Electron_Number              192 non-null    float64
#  11  Martynov_Batsanov_Electronegativity  192 non-null    float64
#  12  Ideal_Bond_Length_Sum                192 non-null    float64
#  13  Mendeleev_Number                     192 non-null    float64
#  14  Formability                          192 non-null    int64
# dtypes: float64(10), int64(1), object(4)
# memory usage: 22.6+ KB

# %% [markdown]
# #### $INFERENCE$ - EXCEPT THE 1ST COLUMN 'MATERIAL' REST ALL ARE NUMERIC VALUES

# %%
# shape
print("Data Size  :" ,df.size)
print("Data Shape :" ,df.shape)
# Out:
# Data Size  : 2880
# Data Shape : (192, 15)

# %%
#Checking number of unique rows in each feature

df.nunique()
# Out:
# Compound                                24
# x(BiMe1Me2)O3                           46
# Me1                                     11
# Me2                                     13
# Me3                                      1
# frac-Me1                                27
# frac-Me2                                27
# frac-Me3                                 2
# PT-content                              46
# Tolerance_Factor                       146
# Valence_Electron_Number                 58
# Martynov_Batsanov_Electronegativity    167
# Ideal_Bond_Length_Sum                  174
# Mendeleev_Number                       159
# Formability                              2
# dtype: int64

# %%
target = 'Formability'
labels = [0, 1]
features = [i for i in df.columns.values if i not in [target]]

# %%
#Checking number of unique rows in each feature

nu = df[features].nunique().sort_values()
nf = []; cf = []; nnf = 0; ncf = 0; #numerical & categorical features

for i in range(df[features].shape[1]):
    if nu.values[i]<=7:cf.append(nu.index[i])
    else: nf.append(nu.index[i])

print('\n\033[1mInference:\033[0m The Datset has {} numerical & {} categorical features.'.format(len(nf),len(cf)))
# Out:
# Inference: The Datset has 12 numerical & 2 categorical features.

# %%
# Get summary statistics
df.describe()
# Out:
#        x(BiMe1Me2)O3    frac-Me1    frac-Me2    frac-Me3  PT-content  \
# count     192.000000  192.000000  192.000000  192.000000  192.000000
# mean        0.412245    0.542626    0.439145    0.018229    0.587755
# std         0.210403    0.140957    0.150179    0.065170    0.210403
# min         0.000000    0.050000    0.120000    0.000000    0.000000
# 25%         0.278750    0.500000    0.330000    0.000000    0.460000
# 50%         0.400000    0.500000    0.500000    0.000000    0.600000
# 75%         0.540000    0.670000    0.500000    0.000000    0.721250
# max         1.000000    0.880000    0.950000    0.250000    1.000000
#
#        Tolerance_Factor  Valence_Electron_Number  \
# count        192.000000               192.000000
# mean           0.987693                 8.909010
# std            0.019939                 1.347192
# min            0.922300                 7.995000
# 25%            0.977300                 8.000000
# 50%            0.985650                 8.000000
# 75%            1.002650                 9.500000
# max            1.027200                14.750000
#
#        Martynov_Batsanov_Electronegativity  Ideal_Bond_Length_Sum  \
# count                           192.000000             192.000000
# mean                              3.764737               3.910678
# std                               0.069449               0.027078
# min                               3.510000               3.846200
# 25%                               3.736750               3.892700
# 50%                               3.754000               3.913250
# 75%                               3.788625               3.931050
# max                               4.100000               3.987500
#
#        Mendeleev_Number  Formability
# count        192.000000   192.000000
# mean         127.713037     0.651042
# std            7.674218     0.477887
# min           99.700000     0.000000
# 25%          122.155000     0.000000
# 50%          127.550000     1.000000
# 75%          133.311500     1.000000
# max          147.850000     1.000000

# %%
# CHECKING OUT FOR NULL VALUES
df.isnull().sum()
# Out:
# Compound                               0
# x(BiMe1Me2)O3                          0
# Me1                                    0
# Me2                                    0
# Me3                                    0
# frac-Me1                               0
# frac-Me2                               0
# frac-Me3                               0
# PT-content                             0
# Tolerance_Factor                       0
# Valence_Electron_Number                0
# Martynov_Batsanov_Electronegativity    0
# Ideal_Bond_Length_Sum                  0
# Mendeleev_Number                       0
# Formability                            0
# dtype: int64

# %%
# Counting the number of duplicates
num_duplicates = df.duplicated().sum()
print("Number of duplicates rows in dataset:   ", num_duplicates)
# Out:
# Number of duplicates rows in dataset:    2

# %% [markdown]
# ### $INFERENCE$ - NO NULL OR MISSING VALUES or DUPLICATE VALUES

# %% [markdown]
# ---

# %% [markdown]
#  <a id="#4"></a>
#
#  <p style="
#     padding: 10px;
#     background-color: darkgreen;
#     margin: 0;
#     color: #ffffff;
#     font-family: 'Trebuchet';
#     font-size: 24px;
#     text-align: center;
#     border: 3px solid green;
#     border-radius: 10px 30px;
#     overflow: hidden;
#     font-weight: bold;
#     text-transform: uppercase;
# ">Data Visualization</p>

# %%
categorical_columns = df.select_dtypes(include=['object'])

# If you want to include columns with integer data type as well, you can do:
numeric_columns = df.select_dtypes(include=['number'])

# If you want to exclude certain columns from the numerical or categorical DataFrame, you can use drop
# For example, if 'Me3' is considered categorical but mistakenly detected as numeric:
# numeric_columns = numeric_columns.drop(columns=['Me3'])

print("\nCategorical DataFrame:")
categorical_columns.head()
# Out:
# Categorical DataFrame:
#    Compound Me1 Me2 Me3
# 0  Bi(GaSc)  Ga  Sc  Ti
# 1  Bi(GaSc)  Ga  Sc  Ti
# 2  Bi(GaSc)  Ga  Sc  Ti
# 3  Bi(GaSc)  Ga  Sc  Ti
# 4  Bi(GaSc)  Ga  Sc  Ti

# %%
# Display the first few rows of each DataFrame to verify the separation
print("Numerical DataFrame:")
numeric_columns.head()
# Out:
# Numerical DataFrame:
#    x(BiMe1Me2)O3  frac-Me1  frac-Me2  frac-Me3  PT-content  Tolerance_Factor  \
# 0           0.45      0.25      0.75       0.0        0.55            0.9813
# 1           0.40      0.25      0.75       0.0        0.60            0.9864
# 2           0.38      0.25      0.75       0.0        0.62            0.9884
# 3           0.36      0.25      0.75       0.0        0.64            0.9904
# 4           0.30      0.25      0.75       0.0        0.70            0.9966
#
#    Valence_Electron_Number  Martynov_Batsanov_Electronegativity  \
# 0                      8.0                               3.7395
# 1                      8.0                               3.7440
# 2                      8.0                               3.7458
# 3                      8.0                               3.7476
# 4                      8.0                               3.7530
#
#    Ideal_Bond_Length_Sum  Mendeleev_Number  Formability
# 0                 3.9208          118.9375            0
# 1                 3.9215          119.5000            0
# 2                 3.9218          119.7250            0
# 3                 3.9221          119.9500            0
# 4                 3.9229          120.6250            1

# %% [markdown]
#  <a id="4.5"></a>
# <p style="
#     padding: 6px;
#     background-color: green;
#     margin: 2px 100px 2px 0px;
#     color: #ffffff;
#     font-family: 'Trebuchet';
#     font-size: 16px;
#     text-align: center;
#     border: 3px solid green;
#     border-radius: 20px 50px;
#     overflow: hidden;
#     font-weight: bold;
#     text-transform: uppercase;
# ">Correlation Heatmap</p>

# %%
# the correlation matrix
corr_matrix = numeric_columns.corr()

# %%
# Correlation heatmap
corr = numeric_columns.corr(method='kendall')
plt.figure(figsize=(10, 7))
sns.heatmap(corr, vmax=.3, linewidths=0.05, annot=True, cmap='RdBu', linecolor="black")
plt.title('Correlation between features', weight = 'heavy')
plt.show()

# %%
corr_matrix1 = corr_matrix.abs()
upper_tri = corr_matrix1.where(np.triu(np.ones(corr_matrix1.shape), k=1).astype(np.bool_))

# %%
sns.set_style('dark')
plt.figure(figsize=(12, 5))
matrix = np.triu(corr_matrix)
sns.heatmap(numeric_columns.corr(), annot = True, linewidth = .8, mask = matrix, cmap = 'RdBu', cbar = True)
# Out:
# <Axes: >

# %%
# PLOTTING THE MOST CORRELATING FEATURES
plt.figure(figsize=(4, 7)) 
heatmap = sns.heatmap(numeric_columns.corr()[['Formability']].sort_values(['Formability'], ascending = False), annot = True, cmap = 'viridis')

# %% [markdown]
#  <a id="4.1"></a>
#  <p style="
#     padding: 17px;
#     background-color: green;
#     margin: px 100px 2px 0px;
#     color: #ffffff;
#     font-family: 'Trebuchet';
#     font-size: 25px;
#     text-align: center;
#     border: 3px solid green;
#     border-radius: 20px 50px;
#     overflow: hidden;
#     font-weight: bold;
#     text-transform: uppercase;
# ">Histograms and Distribution Plots</p>

# %% [markdown]
#  <a id="4.5"></a>
# <p style="
#     padding: 6px;
#     background-color: green;
#     margin: 2px 100px 2px 0px;
#     color: #ffffff;
#     font-family: 'Trebuchet';
#     font-size: 16px;
#     text-align: center;
#     border: 3px solid green;
#     border-radius: 20px 50px;
#     overflow: hidden;
#     font-weight: bold;
#     text-transform: uppercase;
# ">Distribution Plots by Target Variable</p>

# %%
colors=['orange', 'green']

# %%
# Distribution plots of numerical variables by target variable
plt.figure(figsize=(15, 12))
plt.suptitle('Distribution Plot', y=1, weight='bold', fontsize=18)

for n, col in enumerate(numeric_columns):
    plt.subplot(4, 3, n + 1)
    sns.histplot(data=numeric_columns, x=col, kde=True, hue='Formability', palette=colors)
    plt.title(f'Distribution of {col} by Formability')

plt.tight_layout()
plt.show()

# %% [markdown]
#  <a id="4.2"></a>
# <p style="
#     padding: 6px;
#     background-color: green;
#     margin: 2px 100px 2px 0px;
#     color: #ffffff;
#     font-family: ''Trebuchet';
#     font-size: 16px;
#     text-align: center;
#     border: 3px solid green;
#     border-radius: 20px 50px;
#     overflow: hidden;
#     font-weight: bold;
#     text-transform: uppercase;
# ">Box Plots</p>

# %%
# Box plots for numerical variables
plt.figure(figsize=(14, 14))
plt.suptitle('Box Plot', weight='bold', fontsize=18)  

for n, col in enumerate(numeric_columns):
    plt.subplot(4, 3, n + 1)
    sns.boxplot(data=numeric_columns, x='Formability', y=col, hue='Formability', palette=colors)
    plt.title(f'{col}', weight='bold')
    plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
#  <a id="4.4"></a>
#  <p style="
#     padding: 6px;
#     background-color: green;
#     margin: 2px 100px 2px 0px;
#     color: #ffffff;
#     font-family: ''Trebuchet';
#     font-size: 16px;
#     text-align: center;
#     border: 3px solid green;
#     border-radius: 20px 50px;
#     overflow: hidden;
#     font-weight: bold;
#     text-transform: uppercase;
# "> Pie Plots</p>

# %%
fig, axes = plt.subplots(ncols=2, figsize=(11, 4))
colors=['green', 'orange']
# Pie chart for 'Perovskite Stability'
counts = df['Formability'].value_counts()
labels = ['Stable', 'Not stable']

axes[0].pie(counts, labels=labels, autopct='%.0f%%', startangle=90, explode=[0.04, 0.01],colors=colors, textprops={'fontsize': 15})
axes[0].set_title('Data Outcome Distribution - Pie Chart')
axes[1].bar(labels, counts, color= colors)


for i, count in enumerate(counts):
    axes[1].text(i, count, str(count), ha='center', va='bottom', fontsize=12, color='black')

axes[1].set_title('Data Outcome Distribution - Bar Chart')
axes[1].set_ylabel('Count',fontsize=21)
plt.tight_layout()
plt.show()

# %% [markdown]
#  <a id="5"></a>
#
# <p style="
#     padding: 10px;
#     background-color: darkgreen;
#     margin: 0;
#     color: #ffffff;
#     font-family: 'Trebuchet';
#     font-size: 24px;
#     text-align: center;
#     border: 3px solid green;
#     border-radius: 10px 30px;
#     overflow: hidden;
#     font-weight: bold;
#     text-transform: uppercase;
# ">Data Preprocessing</p>

# %%
categorical_columns.head()
# Out:
#    Compound Me1 Me2 Me3
# 0  Bi(GaSc)  Ga  Sc  Ti
# 1  Bi(GaSc)  Ga  Sc  Ti
# 2  Bi(GaSc)  Ga  Sc  Ti
# 3  Bi(GaSc)  Ga  Sc  Ti
# 4  Bi(GaSc)  Ga  Sc  Ti

# %%
# Perform one-hot encoding on categorical columns
categorical_encoded = pd.get_dummies(categorical_columns)

# Concatenate numerical columns with the one-hot encoded categorical columns
df_encoded = pd.concat([numeric_columns, categorical_encoded], axis=1)

# Display the first few rows of the encoded DataFrame
df_encoded.head()
# Out:
#    x(BiMe1Me2)O3  frac-Me1  frac-Me2  frac-Me3  PT-content  Tolerance_Factor  \
# 0           0.45      0.25      0.75       0.0        0.55            0.9813
# 1           0.40      0.25      0.75       0.0        0.60            0.9864
# 2           0.38      0.25      0.75       0.0        0.62            0.9884
# 3           0.36      0.25      0.75       0.0        0.64            0.9904
# 4           0.30      0.25      0.75       0.0        0.70            0.9966
#
#    Valence_Electron_Number  Martynov_Batsanov_Electronegativity  \
# 0                      8.0                               3.7395
# 1                      8.0                               3.7440
# 2                      8.0                               3.7458
# 3                      8.0                               3.7476
# 4                      8.0                               3.7530
#
#    Ideal_Bond_Length_Sum  Mendeleev_Number  ...  Me2_Mg  Me2_Mn  Me2_Nb  \
# 0                 3.9208          118.9375  ...   False   False   False
# 1                 3.9215          119.5000  ...   False   False   False
# 2                 3.9218          119.7250  ...   False   False   False
# 3                 3.9221          119.9500  ...   False   False   False
# 4                 3.9229          120.6250  ...   False   False   False
#
#    Me2_Sc  Me2_Ti  Me2_W  Me2_Yb  Me2_Zn  Me2_Zr  Me3_Ti
# 0    True   False  False   False   False   False    True
# 1    True   False  False   False   False   False    True
# 2    True   False  False   False   False   False    True
# 3    True   False  False   False   False   False    True
# 4    True   False  False   False   False   False    True
#
# [5 rows x 60 columns]

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 60 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   x(BiMe1Me2)O3                        192 non-null    float64
#  1   frac-Me1                             192 non-null    float64
#  2   frac-Me2                             192 non-null    float64
#  3   frac-Me3                             192 non-null    float64
#  4   PT-content                           192 non-null    float64
#  5   Tolerance_Factor                     192 non-null    float64
#  6   Valence_Electron_Number              192 non-null    float64
#  7   Martynov_Batsanov_Electronegativity  192 non-null    float64
#  8   Ideal_Bond_Length_Sum                192 non-null    float64
#  9   Mendeleev_Number                     192 non-null    float64
#  10  Formability                          192 non-null    int64
#  11  Compound_BF                          192 non-null    bool
#  12  Compound_Bi(GaSc)                    192 non-null    bool
#  13  Compound_Bi(MgNb)                    192 non-null    bool
#  14  Compound_Bi(MgTi)                    192 non-null    bool
#  15  Compound_Bi(MgW)                     192 non-null    bool
#  16  Compound_Bi(NiNb)                    192 non-null    bool
#  17  Compound_Bi(NiTi)                    192 non-null    bool
#  18  Compound_Bi(ScFe)                    192 non-null    bool
#  19  Compound_Bi(ScMgTi)                  192 non-null    bool
#  20  Compound_Bi(ScZnTi)                  192 non-null    bool
#  21  Compound_Bi(ZnNb)                    192 non-null    bool
#  22  Compound_Bi(ZnW)                     192 non-null    bool
#  23  Compound_Bi(ZnZr)                    192 non-null    bool
#  24  Compound_BiCoFe                      192 non-null    bool
#  25  Compound_BiGa                        192 non-null    bool
#  26  Compound_BiIn                        192 non-null    bool
#  27  Compound_BiLu                        192 non-null    bool
#  28  Compound_BiMgTi                      192 non-null    bool
#  29  Compound_BiMgZr                      192 non-null    bool
#  30  Compound_BiMn                        192 non-null    bool
#  31  Compound_BiSc                        192 non-null    bool
#  32  Compound_BiScIn                      192 non-null    bool
#  33  Compound_BiYb                        192 non-null    bool
#  34  Compound_BiZnTi                      192 non-null    bool
#  35  Me1_Co                               192 non-null    bool
#  36  Me1_Fe                               192 non-null    bool
#  37  Me1_Ga                               192 non-null    bool
#  38  Me1_In                               192 non-null    bool
#  39  Me1_Lu                               192 non-null    bool
#  40  Me1_Mg                               192 non-null    bool
#  41  Me1_Mn                               192 non-null    bool
#  42  Me1_Ni                               192 non-null    bool
#  43  Me1_Sc                               192 non-null    bool
#  44  Me1_Yb                               192 non-null    bool
#  45  Me1_Zn                               192 non-null    bool
#  46  Me2_Fe                               192 non-null    bool
#  47  Me2_Ga                               192 non-null    bool
#  48  Me2_In                               192 non-null    bool
#  49  Me2_Lu                               192 non-null    bool
#  50  Me2_Mg                               192 non-null    bool
#  51  Me2_Mn                               192 non-null    bool
#  52  Me2_Nb                               192 non-null    bool
#  53  Me2_Sc                               192 non-null    bool
#  54  Me2_Ti                               192 non-null    bool
#  55  Me2_W                                192 non-null    bool
#  56  Me2_Yb                               192 non-null    bool
#  57  Me2_Zn                               192 non-null    bool
#  58  Me2_Zr                               192 non-null    bool
#  59  Me3_Ti                               192 non-null    bool
# dtypes: bool(49), float64(10), int64(1)
# memory usage: 25.8 KB

# %%
# splitting into independant and target features
X = df_encoded.drop(columns = ['Formability'])
y= df_encoded['Formability']

# %%
X.head()
# Out:
#    x(BiMe1Me2)O3  frac-Me1  frac-Me2  frac-Me3  PT-content  Tolerance_Factor  \
# 0           0.45      0.25      0.75       0.0        0.55            0.9813
# 1           0.40      0.25      0.75       0.0        0.60            0.9864
# 2           0.38      0.25      0.75       0.0        0.62            0.9884
# 3           0.36      0.25      0.75       0.0        0.64            0.9904
# 4           0.30      0.25      0.75       0.0        0.70            0.9966
#
#    Valence_Electron_Number  Martynov_Batsanov_Electronegativity  \
# 0                      8.0                               3.7395
# 1                      8.0                               3.7440
# 2                      8.0                               3.7458
# 3                      8.0                               3.7476
# 4                      8.0                               3.7530
#
#    Ideal_Bond_Length_Sum  Mendeleev_Number  ...  Me2_Mg  Me2_Mn  Me2_Nb  \
# 0                 3.9208          118.9375  ...   False   False   False
# 1                 3.9215          119.5000  ...   False   False   False
# 2                 3.9218          119.7250  ...   False   False   False
# 3                 3.9221          119.9500  ...   False   False   False
# 4                 3.9229          120.6250  ...   False   False   False
#
#    Me2_Sc  Me2_Ti  Me2_W  Me2_Yb  Me2_Zn  Me2_Zr  Me3_Ti
# 0    True   False  False   False   False   False    True
# 1    True   False  False   False   False   False    True
# 2    True   False  False   False   False   False    True
# 3    True   False  False   False   False   False    True
# 4    True   False  False   False   False   False    True
#
# [5 rows x 59 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 187    1
# 188    0
# 189    1
# 190    1
# 191    1
# Name: Formability, Length: 192, dtype: int64

# %% [markdown]
#  <a id="5.1"></a>
#
# <p style="
#     padding: 10px;
#     background-color: darkgreen;
#     margin: 0;
#     color: #ffffff;
#     font-family: 'Trebuchet';
#     font-size: 24px;
#     text-align: center;
#     border: 3px solid green;
#     border-radius: 10px 30px;
#     overflow: hidden;
#     font-weight: bold;
#     text-transform: uppercase;
# ">Feature Scaling</p>

# %%
## standardize the dataset

from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()

# %%
X_scaled = std_scaler.fit_transform(X)
X_scaled
# Out:
# array([[ 0.17991182, -2.08141816,  2.07530355, ..., -0.1796053 ,
#         -0.24652278,  0.        ],
#        [-0.05834911, -2.08141816,  2.07530355, ..., -0.1796053 ,
#         -0.24652278,  0.        ],
#        [-0.15365348, -2.08141816,  2.07530355, ..., -0.1796053 ,
#         -0.24652278,  0.        ],
#        ...,
#        [-0.7731319 , -0.51658106,  0.60655909, ..., -0.1796053 ,
#         -0.24652278,  0.        ],
#        [-1.01139284,  2.39970626, -2.13064651, ..., -0.1796053 ,
#         -0.24652278,  0.        ],
#        [-0.05834911,  1.90180355, -1.66331873, ..., -0.1796053 ,
#         -0.24652278,  0.        ]])

# %% [markdown]
#  <a id="595"></a>
#
# <p style="
#     padding: 10px;
#     background-color: darkgreen;
#     margin: 0;
#     color: #ffffff;
#     font-family: 'Trebuchet';
#     font-size: 24px;
#     text-align: center;
#     border: 3px solid green;
#     border-radius: 10px 30px;
#     overflow: hidden;
#     font-weight: bold;
#     text-transform: uppercase;
# ">Training and Testing Dataset</p>

# %%
### Train test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled,y, test_size= 0.2, random_state=40, stratify = y)

# %%
print('Original set  ---> ',X.shape,y.shape,'\nTraining set  ---> ',X_train.shape, y_train.shape,'\nTesting set   ---> ', X_test.shape,'', y_test.shape)
# Out:
# Original set  --->  (192, 59) (192,)
# Training set  --->  (153, 59) (153,)
# Testing set   --->  (39, 59)  (39,)

# %%
## standardize the dataset

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %% [markdown]
#  <a id="7"></a>
#
# <p style="
#     padding: 10px;
#     background-color: darkgreen;
#     margin: 0;
#     color: #ffffff;
#     font-family: 'Trebuchet';
#     font-size: 24px;
#     text-align: center;
#     border: 3px solid green;
#     border-radius: 10px 30px;
#     overflow: hidden;
#     font-weight: bold;
#     text-transform: uppercase;
# ">Model Building </p>

# %% [markdown]
# List of Models
# <ul>
#       <li> 1. Logistic regression</li>
#       <li> 2. Decision Tree Classifier</li>
#       <li> 3. Random Forest Classifier</li>
#       <li> 4. ExtraTrees Classifier</li>
#       <li> 5. Support Vector Classifier</li>
#       <li> 6. K Neighbours Classifier</li>
#       <li> 7. GradientBoost Classifier</li>
#       <li> 8. Naive-Bayes</li>
#       <li> 9. AdaBoost Classifier</li>
# </div>

# %% [markdown]
# ### Importing the libraries for model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier 
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier 
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# ### Creating the object of the model :

# %%
LR  = LogisticRegression()
DT  = DecisionTreeClassifier()
RF  = RandomForestClassifier()
ETC = ExtraTreesClassifier()
SVM = SVC()
KNN = KNeighborsClassifier()
GBC = GradientBoostingClassifier() 
NB  = GaussianNB()
ABC = AdaBoostClassifier()

# %%
from sklearn.model_selection import cross_val_score

# %%
models = [LR, DT, RF, ETC, SVM, KNN , GBC, ABC, NB]
features = X_scaled
labels = y
CV = 10 # cross validation
accu_list = [] # Accuracy list
ModelName = [] #Model Name list

for model in models:
    model_name = model.__class__.__name__
    accuracies = cross_val_score(model, features, labels, scoring = 'accuracy', cv= CV)
    accu_list.append(accuracies.mean()*100)
    ModelName.append(model_name)

    
model_acc_df = pd.DataFrame({"Model"  :  ModelName, "Cross_Val_Accuracy" : accu_list})
model_acc_df = model_acc_df.sort_values(by='Cross_Val_Accuracy', ascending=False)
model_acc_df
# Out:
#                         Model  Cross_Val_Accuracy
# 2      RandomForestClassifier           76.500000
# 1      DecisionTreeClassifier           76.473684
# 7          AdaBoostClassifier           74.947368
# 0          LogisticRegression           74.921053
# 6  GradientBoostingClassifier           73.342105
# 5        KNeighborsClassifier           71.368421
# 3        ExtraTreesClassifier           69.184211
# 4                         SVC           68.684211
# 8                  GaussianNB           56.157895

# %%
# Sort DataFrame by 'Cross_Val_Accuracy' in descending order
model_acc_df = model_acc_df.sort_values(by='Cross_Val_Accuracy', ascending=False)

# Create a color palette for bars
colors = plt.cm.viridis(np.linspace(0, 1, len(model_acc_df)))

# Create bar plot
plt.figure(figsize=(10, 6))
bars = plt.bar(model_acc_df["Model"], model_acc_df["Cross_Val_Accuracy"], color=colors)
plt.xlabel('Model')
plt.ylabel('Cross-Validation Accuracy')
plt.title('Cross-Validation Accuracy for Different Models (Highest to Lowest)')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.ylim(40, 80)  # Set y-axis limits

# Add values on top of the bars
for bar, value in zip(bars, model_acc_df["Cross_Val_Accuracy"]):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.15, bar.get_height() + 0.5,
             f'{value:.2f}', ha='center', va='bottom', color='black')

plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# Taking the top three models for further analysis

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, \
f1_score, roc_auc_score, roc_curve, precision_score, recall_score

# %%
DT.fit(X_train, y_train)
y_pred_dt = DT.predict(X_test)

ABC.fit(X_train, y_train)
y_pred_abc = ABC.predict(X_test)

RF.fit(X_train, y_train)
y_pred_rf = RF.predict(X_test)

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71        14
#            1       0.84      0.84      0.84        25
#
#     accuracy                           0.79        39
#    macro avg       0.78      0.78      0.78        39
# weighted avg       0.79      0.79      0.79        39

# %%
print(classification_report(y_test, y_pred_abc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.71      0.67        14
#            1       0.83      0.76      0.79        25
#
#     accuracy                           0.74        39
#    macro avg       0.73      0.74      0.73        39
# weighted avg       0.75      0.74      0.75        39

# %%
print(classification_report(y_test, y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79        14
#            1       0.88      0.88      0.88        25
#
#     accuracy                           0.85        39
#    macro avg       0.83      0.83      0.83        39
# weighted avg       0.85      0.85      0.85        39

# %%
from sklearn.metrics import roc_curve, auc
y_scores = DT.predict_proba(X_test)[:, 1]

fpr, tpr, thresholds = roc_curve(y_test, y_scores)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(5, 4))

plt.plot(fpr, tpr, color= 'blue', lw=2, label=f'ROC curve of DT (area = {roc_auc})')
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
y_scores = RF.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_scores)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(5, 4))

plt.plot(fpr, tpr, color= 'blue', lw=2, label=f'ROC curve of RF (area = {roc_auc})')
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
y_scores = ABC.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_scores)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(5, 4))

plt.plot(fpr, tpr, color= 'blue', lw=2, label=f'ROC curve of ABC (area = {roc_auc})')
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
#  <a id="7"></a>
#
# <p style="
#     padding: 10px;
#     background-color: darkgreen;
#     margin: 0;
#     color: #ffffff;
#     font-family: 'Trebuchet';
#     font-size: 24px;
#     text-align: center;
#     border: 3px solid green;
#     border-radius: 10px 30px;
#     overflow: hidden;
#     font-weight: bold;
#     text-transform: uppercase;
# ">Top 3 Model Evaluation  </p>

# %% [markdown]
# #####  Let us create first create a table to store the results of various models

# %%
Evaluation_Results = pd.DataFrame(np.zeros((3,5)), columns=['Accuracy', 'Precision','Recall','F1-score','AUC-ROC score'])
Evaluation_Results.index=['Random Forest Classifier (RF)', 'Decision Tree (DT)', 'AdaBoostClassifier(AB)']
Evaluation_Results
# Out:
#                                Accuracy  Precision  Recall  F1-score  \
# Random Forest Classifier (RF)       0.0        0.0     0.0       0.0
# Decision Tree (DT)                  0.0        0.0     0.0       0.0
# AdaBoostClassifier(AB)              0.0        0.0     0.0       0.0
#
#                                AUC-ROC score
# Random Forest Classifier (RF)            0.0
# Decision Tree (DT)                       0.0
# AdaBoostClassifier(AB)                   0.0

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

def Classification_Summary(y_test, y_pred_best, i, Evaluation_Results):
    Evaluation_Results.iloc[i]['Accuracy'] = round(accuracy_score(y_test, y_pred_best), 3) * 100   
    Evaluation_Results.iloc[i]['Precision'] = round(precision_score(y_test, y_pred_best, average='micro'), 3) * 100
    Evaluation_Results.iloc[i]['Recall'] = round(recall_score(y_test, y_pred_best, average='micro'), 3) * 100
    Evaluation_Results.iloc[i]['F1-score'] = round(f1_score(y_test, y_pred_best, average='micro'), 3) * 100

    print('{}{}\033[1m Evaluating {} \033[0m{}{}\n'.format('<'*3, '-'*25, Evaluation_Results.index[i], '-'*25, '>'*3))
    print('Accuracy = {}%'.format(round(accuracy_score(y_test, y_pred_best), 3) * 100))
    print('F1 Score = {}%'.format(round(f1_score(y_test, y_pred_best, average='micro'), 3) * 100))
    print('\n \033[1mConfusion Matrix:\033[0m\n', confusion_matrix(y_test, y_pred_best))
    print('\n\033[1mClassification Report:\033[0m\n', classification_report(y_test, y_pred_best))

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Random Forest Classfier:

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# Assuming you have X_train, X_test, y_train, and y_test defined

params_RF = {"min_samples_split": [2, 6],
             "min_samples_leaf": [1, 4],
             "n_estimators": [100, 200, 300],
             "criterion": ["gini", 'entropy']
            }

cv_method = StratifiedKFold(n_splits=3)

GridSearchCV_RF = GridSearchCV(estimator=RandomForestClassifier(),
                                param_grid=params_RF,
                                cv=cv_method,
                                verbose=1,
                                n_jobs=2,
                                scoring="accuracy",
                                return_train_score=True
                                )

GridSearchCV_RF.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=3, random_state=None, shuffle=False),
#              estimator=RandomForestClassifier(), n_jobs=2,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'min_samples_leaf': [1, 4],
#                          'min_samples_split': [2, 6],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='accuracy', verbose=1)

# %%
best_params_RF = GridSearchCV_RF.best_params_
print("Best Hyperparameters for Random Forest are = \n", best_params_RF)

best_estimator = GridSearchCV_RF.best_estimator_
y_pred_best = best_estimator.predict(X_test)
# Out:
# Best Hyperparameters for Random Forest are =
#  {'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}

# %%
Classification_Summary(y_test, y_pred_best, 0, Evaluation_Results)
# Out:
# <<<------------------------- Evaluating Random Forest Classifier (RF) ------------------------->>>
#
# Accuracy = 76.9%
# F1 Score = 76.9%
#
#  Confusion Matrix:
#  [[ 9  5]
#  [ 4 21]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.69      0.64      0.67        14
#            1       0.81      0.84      0.82        25
#
#     accuracy                           0.77        39
#    macro avg       0.75      0.74      0.75        39
# weighted avg       0.77      0.77      0.77        39

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Decision Tree Classfier:

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier

# Define the parameter grid for DecisionTreeClassifier
params_DT = {
    'max_depth': [3, 4, 5],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Define the cross-validation method
cv_method = StratifiedKFold(n_splits=3)

# Instantiate the GridSearchCV object
GridSearchCV_DT = GridSearchCV(estimator=DecisionTreeClassifier(),
                                param_grid=params_DT,
                                cv=cv_method,
                                verbose=1,
                                n_jobs=2,
                                scoring='accuracy',
                                return_train_score=True)

# Fit the GridSearchCV object to the training data
GridSearchCV_DT.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=3, random_state=None, shuffle=False),
#              estimator=DecisionTreeClassifier(), n_jobs=2,
#              param_grid={'max_depth': [3, 4, 5], 'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              return_train_score=True, scoring='accuracy', verbose=1)

# %%
# Get the best parameters
best_params_DT = GridSearchCV_DT.best_params_
print("Best Hyperparameters for Decision Tree are = \n", best_params_DT)

# Get the best estimator
best_estimator_DT = GridSearchCV_DT.best_estimator_

# Fit the best estimator on the training data
best_estimator_DT.fit(X_train, y_train)

# Make predictions on the test data
y_pred_best_DT = best_estimator_DT.predict(X_test)
# Out:
# Best Hyperparameters for Decision Tree are =
#  {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
# Print the classification report
Classification_Summary(y_test, y_pred_best_DT, 1, Evaluation_Results)
# Out:
# <<<------------------------- Evaluating Decision Tree (DT) ------------------------->>>
#
# Accuracy = 89.7%
# F1 Score = 89.7%
#
#  Confusion Matrix:
#  [[11  3]
#  [ 1 24]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85        14
#            1       0.89      0.96      0.92        25
#
#     accuracy                           0.90        39
#    macro avg       0.90      0.87      0.88        39
# weighted avg       0.90      0.90      0.90        39

# %% [markdown]
# -------

# %% [markdown]
# ## 3. Ada Boost Classfier:

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.ensemble import AdaBoostClassifier

# Define the parameter grid
params_AB = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.05, 0.1, 0.2],
    'algorithm': ['SAMME', 'SAMME.R']
}

# Define the cross-validation method
cv_method = StratifiedKFold(n_splits=3)

# Instantiate the GridSearchCV object
GridSearchCV_AB = GridSearchCV(estimator=AdaBoostClassifier(),
                                param_grid=params_AB,
                                cv=cv_method,
                                verbose=1,
                                n_jobs=2,
                                scoring='accuracy',
                                return_train_score=True)

# Fit the GridSearchCV object to the training data
GridSearchCV_AB.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=3, random_state=None, shuffle=False),
#              estimator=AdaBoostClassifier(), n_jobs=2,
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.05, 0.1, 0.2],
#                          'n_estimators': [50, 100, 200]},
#              return_train_score=True, scoring='accuracy', verbose=1)

# %%
# Get the best parameters
best_params_AB = GridSearchCV_AB.best_params_
print("Best Hyperparameters for AdaBoost Classifier are = \n", best_params_AB)

# Get the best estimator
best_estimator_AB = GridSearchCV_AB.best_estimator_

# Fit the best estimator on the training data
best_estimator_AB.fit(X_train, y_train)

# Make predictions on the test data
y_pred_best_AB = best_estimator_AB.predict(X_test)
# Out:
# Best Hyperparameters for AdaBoost Classifier are =
#  {'algorithm': 'SAMME.R', 'learning_rate': 0.2, 'n_estimators': 200}

# %%
# Print the classification report
Classification_Summary(y_test, y_pred_best_AB, 2, Evaluation_Results)
# Out:
# <<<------------------------- Evaluating AdaBoostClassifier(AB) ------------------------->>>
#
# Accuracy = 82.1%
# F1 Score = 82.1%
#
#  Confusion Matrix:
#  [[11  3]
#  [ 4 21]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.79      0.76        14
#            1       0.88      0.84      0.86        25
#
#     accuracy                           0.82        39
#    macro avg       0.80      0.81      0.81        39
# weighted avg       0.82      0.82      0.82        39

# %%
Evaluation_Results
# Out:
#                                Accuracy  Precision  Recall  F1-score  \
# Random Forest Classifier (RF)      76.9       76.9    76.9      76.9
# Decision Tree (DT)                 89.7       89.7    89.7      89.7
# AdaBoostClassifier(AB)             82.1       82.1    82.1      82.1
#
#                                AUC-ROC score
# Random Forest Classifier (RF)            0.0
# Decision Tree (DT)                       0.0
# AdaBoostClassifier(AB)                   0.0

# %% [markdown]
# ##### Decision Tree (DT) MODEL WAS CHOSEN TO BUILD THE FINAL PREDICTION

# %%
# Assuming GridSearchCV_DT is your trained GridSearchCV object
# Select the best estimator from GridSearchCV
best_DT_model = GridSearchCV_DT.best_estimator_

# Make predictions on the test data
y_pred = best_DT_model.predict(X_test)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred) * 100

# Count the occurrences of each unique value in actual and predicted values
actual_counts = y_test.value_counts()
predicted_counts = pd.Series(y_pred).value_counts()

# Create a pie chart for actual values
plt.figure(figsize=(7, 4))
plt.subplot(1, 2, 1)
plt.pie(actual_counts, labels=actual_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Actual Values')

# Create a pie chart for predicted values
plt.subplot(1, 2, 2)
plt.pie(predicted_counts, labels=predicted_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Predicted Values')

# Add accuracy as a title
plt.suptitle(f'Accuracy: {accuracy:.2f}%')

plt.tight_layout()
plt.show()
